# %%
import pandas as pd

# %%
pickle_filepath = '/Users/djbetts/Desktop/jf_project/keyword_fun/keywords_by_mediaComponentId.pkl'

# %%
csv_filepath = '/Users/djbetts/Desktop/jf_project/keyword_fun/mc_keywords.csv'

# %%
pickle_data = pd.read_pickle(pickle_filepath)

# %%
pickled_series = pickle_data.copy()

# %%
pickled_df = pd.DataFrame(pickled_series)

# %%
topic_scores_df = pd.read_csv('/Users/djbetts/Desktop/jf_project/keyword_fun/topic-scores.txt', sep='\t')

# %%
topic_scores_df.drop('# Generated 2021-05-17. CC-BY License: www.openbible.info/topics', axis=1, inplace=True)

# %%
references = topic_scores_df['OSIS']

# %%
def verse_list(keyword_list):
    verse_list = []
    for keyword in keyword_list:
        if ':' in keyword:
            verse_list.append(keyword)
    return verse_list

# %%
# def kill_empty_lists(keyword_list):
#     if keyword_list == []:
#         return None

# %%
pickled_df['verse_list'] = pickled_df['keyword_name'].apply(verse_list)

# %%
#pickled_df['verse_list'].apply(kill_empty_lists)

# %%
for lst in pickled_df['verse_list']:
    for string in (lst):
        if string[0].isdigit():
            print(string)
#            print('\n')
        else:
            print(f'regular: {string}')
# Out:
# regular: luke 1:26
# regular: luke 1:27
# regular: luke 1:28
# regular: luke 1:29
# regular: luke 1:30
# regular: luke 1:31
# regular: luke 1:32
# regular: luke 1:33
# regular: luke 2:1
# regular: luke 2:2
# regular: luke 2:3
# regular: luke 2:4
# regular: luke 2:5
# regular: luke 2:6
# regular: luke 2:7
# regular: luke 2:8
# regular: luke 2:9
# regular: luke 2:11
# regular: luke 2:16
# regular: luke 2:17
# regular: luke 2:18
# regular: luke 2:10
# regular: luke 2:41
# regular: luke 2:42
# regular: luke 2:43
# regular: luke 2:44
# regular: luke 2:45
# regular: luke 2:46
# regular: luke 2:47
# regular: luke 2:48
# regular: luke 2:49
# regular: luke 2:51
# regular: luke 2:52
# regular: luke 2:50
# regular: luke 5:4
# regular: luke 5:6
# regular: luke 5:7
# regular: luke 5:8
# regular: luke 5:9
# regular: luke 5:10
# regular: luke 5:11
# regular: luke 5:5
# regular: luke 5:3
# regular: luke 5:1
# regular: luke 5:2
# regular: luke 8:41
# regular: luke 8:42
# regular: luke 8:49
# ...

# %%
t = pickled_df['verse_list']

# %%
result = []
[result.extend(ref_list) for ref_list in list(pickled_df['verse_list'])]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
flat_list = [item for sublist in t for item in sublist]

# %%
flat_set = [ref.split(' ')[0] for ref in flat_list]

# %%
flat_set = set(flat_set)

# %%
flat_set
# Out:
# {'',
#  '1',
#  '12:22-28',
#  '2',
#  '20:11',
#  '21:1-4',
#  '28-36;',
#  '5:27-28',
#  '5:8',
#  '6',
#  '6:12-16',
#  '6:23',
#  '7',
#  '8',
#  '8:27-56',
#  'act',
#  'acts',
#  'colossians',
#  'daniel',
#  'day',
#  'deuteronomy',
#  'dias',
#  'ephesians',
#  'galatians',
#  'genesis',
#  'hebrews',
#  'isaiah',
#  'james',
#  'john',
#  'joshua',
#  'luke',
#  'luke18:35',
#  'luke18:36',
#  'luke18:37',
#  'luke18:38',
#  'luke18:39',
#  'luke18:40',
#  'luke18:41',
#  'luke18:42',
#  'luke18:43',
#  'mark',
#  'matthew',
#  'philippians',
#  'power.',
#  'proverbs',
#  'psalm',
#  'romans'}

# %%
topic_scores_df['OSIS'].value_counts()
# Out:
# John.3.16                372
# Rom.12.2                 305
# 1John.1.9                253
# Jer.29.11                226
# 1Tim.5.8                 225
#                         ...
# Exod.40.2                  1
# Luke.11.23                 1
# Luke.10.38-Luke.11.54      1
# Rom.16.3-Rom.16.4          1
# Neh.4.13-Neh.4.14          1
# Name: OSIS, Length: 12226, dtype: int64

# %%
len(topic_scores_df['OSIS'])
# Out:
# 57502

# %%
topic_scores_df['score'] = topic_scores_df['Quality Score (based on percentage of votes for the passage)']

# %%
sum(topic_scores_df['score'] < 10)
# Out:
# 53193

# %%
over_10 = topic_scores_df[topic_scores_df['score'] > 10]

# %%
over_10
# Out:
#                Topic                 OSIS  \
# 26              2012           Matt.24.36
# 27      2nd marriage            1Cor.7.39
# 32       4th of july            1Pet.2.16
# 33       4th of july            2Cor.3.17
# 55     7 deadly sins  Prov.6.16-Prov.6.19
# ...              ...                  ...
# 57415       yourself              Gal.5.1
# 57416          youth            1Tim.4.12
# 57442      ziggurats   Gen.11.1-Gen.11.32
# 57461   zodiac signs             Jer.27.9
# 57477        zombies           Zech.14.12
#
#        Quality Score (based on percentage of votes for the passage)  score
# 26                                                    30                30
# 27                                                    11                11
# 32                                                    17                17
# 33                                                    11                11
# 55                                                    20                20
# ...

# %%
x = list(topic_scores_df['OSIS'])

# %%
result = []
result.append([el.split('.')[0] for el in x])

# %%
books = set(result[0])

# %%
books = pd.DataFrame(books)

# %%
books.to_csv('openbible_books.csv')

# %%
books_csv = pd.read_csv('/Users/djbetts/Desktop/jf_project/keyword_fun/openbible_books.csv', index_col='Unnamed: 0')

# %%
books_csv.head()
# Out:
#       0
# 0   Mic
# 1  1Pet
# 2  1Sam
# 3  Zeph
# 4   Col
